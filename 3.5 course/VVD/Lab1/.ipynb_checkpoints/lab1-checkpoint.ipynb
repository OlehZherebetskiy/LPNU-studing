# %%
import pandas as pd
import seaborn as sb
import json

# %%
dfBeersReview = pd.read_csv("beer_reviews.csv")
dfBeersRecipe = pd.read_csv("recipeData.csv")

# %%
dfBeersReview.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883

# %%
dfBeersRecipe.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0  17.65  ...        1.038        70.0            NaN  Specific Gravity
# 1  60.65  ...        1.070        70.0            NaN  Specific Gravity
# 2  59.25  ...          NaN        70.0            NaN  Specific Gravity
# 3  54.48  ...          NaN        70.0            NaN  Specific Gravity
# 4  17.84  ...        1.050        72.0            NaN  Specific Gravity
#
#    BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0   All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1   All Grain        NaN         NaN           NaN             NaN    955.0
# 2     extract        NaN         NaN           NaN             NaN      NaN
# 3   All Grain        NaN         NaN           NaN             NaN      NaN
# 4   All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
dfBeersReview = dfBeersReview.drop(columns=["brewery_id", "review_time", "review_profilename", "beer_beerid"])
dfBeersReview.head()
# Out:
#               brewery_name  review_overall  review_aroma  review_appearance  \
# 0          Vecchio Birraio             1.5           2.0                2.5
# 1          Vecchio Birraio             3.0           2.5                3.0
# 2          Vecchio Birraio             3.0           2.5                3.0
# 3          Vecchio Birraio             3.0           3.0                3.5
# 4  Caldera Brewing Company             4.0           4.5                4.0
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv
# 0            Sausa Weizen       5.0
# 1                Red Moon       6.2
# 2  Black Horse Black Beer       6.5
# 3              Sausa Pils       5.0
# 4           Cauldron DIPA       7.7

# %%
dfBeersRecipe = dfBeersRecipe.drop(columns=["URL", "BeerID", "Style", "StyleID", "Size(L)", "MashThickness", "SugarScale", "BrewMethod", "PitchRate", "PrimaryTemp", "PrimingMethod", "PrimingAmount", "UserId", "BoilGravity"])
dfBeersRecipe.head()
# Out:
#                               Name     OG     FG   ABV    IBU  Color  \
# 0                Vanilla Cream Ale  1.055  1.013  5.48  17.65   4.83
# 1      Southern Tier Pumking clone  1.083  1.021  8.16  60.65  15.64
# 2      Zombie Dust Clone - EXTRACT  1.063  1.018  5.91  59.25   8.98
# 3    Zombie Dust Clone - ALL GRAIN  1.061  1.017  5.80  54.48   8.50
# 4  Bakke Brygg Belgisk Blonde 50 l  1.060  1.010  6.48  17.84   4.57
#
#    BoilSize  BoilTime  Efficiency
# 0     28.39        75        70.0
# 1     24.61        60        70.0
# 2     22.71        60        70.0
# 3     26.50        60        70.0
# 4     60.00        90        72.0

# %%
dfBeersRecipe = dfBeersRecipe.rename(columns={'Name': 'beer_name'})
dfBeersRecipe.head()
# Out:
#                          beer_name     OG     FG   ABV    IBU  Color  \
# 0                Vanilla Cream Ale  1.055  1.013  5.48  17.65   4.83
# 1      Southern Tier Pumking clone  1.083  1.021  8.16  60.65  15.64
# 2      Zombie Dust Clone - EXTRACT  1.063  1.018  5.91  59.25   8.98
# 3    Zombie Dust Clone - ALL GRAIN  1.061  1.017  5.80  54.48   8.50
# 4  Bakke Brygg Belgisk Blonde 50 l  1.060  1.010  6.48  17.84   4.57
#
#    BoilSize  BoilTime  Efficiency
# 0     28.39        75        70.0
# 1     24.61        60        70.0
# 2     22.71        60        70.0
# 3     26.50        60        70.0
# 4     60.00        90        72.0

# %%
#dfBeersReview[dfBeersReview['review_overall'].isnull()]
#dfBeersReview[dfBeersReview['review_aroma'].isnull()]
#dfBeersReview[dfBeersReview['review_appearance'].isnull()]
#dfBeersReview[dfBeersReview['review_palate'].isnull()]
#dfBeersReview[dfBeersReview['review_taste'].isnull()]
dfBeersReview[dfBeersReview['beer_abv'].isnull()]
#dfBeersReview[dfBeersReview['beer_name'].isnull()]
#dfBeersReview[dfBeersReview['beer_style'].isnull()]
# Out:
#                         brewery_name  review_overall  review_aroma  \
# 273          Caldera Brewing Company             3.0           3.0
# 430       Moon River Brewing Company             3.5           4.0
# 603       Moon River Brewing Company             4.0           3.5
# 733          Caldera Brewing Company             4.0           4.0
# 798          Caldera Brewing Company             4.5           4.5
# ...                              ...             ...           ...
# 1586568  The Defiant Brewing Company             4.0           3.5
# 1586587  The Defiant Brewing Company             3.5           4.5
# 1586596  The Defiant Brewing Company             4.0           3.0
# 1586597  The Defiant Brewing Company             4.5           4.5
# 1586598  The Defiant Brewing Company             4.0           4.0
#
#          review_appearance                        beer_style  review_palate  \
# 273                    3.0                    American Stout            4.0
# 430                    4.5            Scotch Ale / Wee Heavy            3.5
# 603                    4.0            Scotch Ale / Wee Heavy            3.5
# 733                    4.0                      American IPA            4.0
# 798                    4.0  American Double / Imperial Stout            4.0
# ...                    ...                               ...            ...
# 1586568                4.0                              Bock            4.0
# 1586587                4.0             Maibock / Helles Bock            4.5
# 1586596                5.0           Belgian Strong Pale Ale            4.0
# 1586597                4.0           Belgian Strong Pale Ale            4.0
# 1586598                3.5           Belgian Strong Pale Ale            4.0
#
#          review_taste                beer_name  beer_abv
# 273               3.0  Cauldron Espresso Stout       NaN
# 430               3.5     The Highland Stagger       NaN
# 603               3.5     The Highland Stagger       NaN
# 733               4.0               Alpha Beta       NaN
# 798               4.5           Imperial Stout       NaN
# ...               ...                      ...       ...
# 1586568           4.0                     Bock       NaN
# 1586587           4.0                  Maibock       NaN
# 1586596           3.5            Resolution #2       NaN
# 1586597           4.0            Resolution #2       NaN
# 1586598           4.5            Resolution #2       NaN
#
# [67785 rows x 9 columns]

# %%
dfBeersRecipe[dfBeersRecipe['beer_name'].isnull()]
# Out:
#       beer_name     OG     FG   ABV  IBU  Color  BoilSize  BoilTime  \
# 28051       NaN  1.002  1.001  0.22  0.0   0.53     22.71        60
#
#        Efficiency
# 28051        70.0

# %%
dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
# Out:
# <ipython-input-10-480f56e31ab5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
# <ipython-input-10-480f56e31ab5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
# <ipython-input-10-480f56e31ab5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
# <ipython-input-10-480f56e31ab5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
# <ipython-input-10-480f56e31ab5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfBeersRecipe[dfBeersRecipe['OG']>1.000][dfBeersRecipe['OG']<1.003][dfBeersRecipe['FG']>=1.000][dfBeersRecipe['FG']<=1.002][dfBeersRecipe['ABV']>=0.20][dfBeersRecipe['ABV']<=0.24]
#                   beer_name     OG     FG   ABV    IBU  Color  BoilSize  \
# 28051                   NaN  1.002  1.001  0.22   0.00   0.53     22.71
# 38632      Punkinhead Wheat  1.002  1.001  0.21  19.79   1.18     27.44
# 42917    Spice Cookie Stout  1.002  1.001  0.21   0.00   0.80     28.39
# 62507  Test Custom Mashable  1.002  1.001  0.21   0.00   2.97     28.39
#
#        BoilTime  Efficiency
# 28051        60        70.0
# 38632        60        65.0
# 42917        60        35.0
# 62507        60        70.0

# %%
dfBeersRecipe =  dfBeersRecipe.groupby('beer_name').mean()
dfBeersRecipe
# Out:
#                                         OG       FG    ABV    IBU  Color  \
# beer_name
# \tImperial Nut Brown Maple Chai     1.1070  1.01900  11.55  70.57  30.85
# \tMaple Brown Ale                   1.0730  1.01800   7.23  53.85  22.36
# \tTempe Closet Oatmeal Milk Brown  16.4312  7.03775   5.17  25.86  21.16
# !!! Citra Pale !!!                  1.0660  1.01700   6.50  60.52   7.13
# !!! IPA !!!                         1.0760  1.01900   7.50  72.36  10.48
# ...                                    ...      ...    ...    ...    ...
# �vralids old oak                    1.0720  1.02000   6.82  35.88  15.07
# �vslapps�l                          1.0690  1.01900   6.56  73.46   9.24
# �yvind porter                       1.0950  1.01800  10.12  45.67  39.38
# ��gua de Col�nia                    1.0450  1.00700   4.89  22.53   5.62
# ��rea de Prote��o Ambiental         1.0470  1.01200   4.62  24.87   6.00
#
#                                    BoilSize  BoilTime  Efficiency
# beer_name
# \tImperial Nut Brown Maple Chai       28.39      60.0        65.0
# \tMaple Brown Ale                     30.28      60.0        75.0
# \tTempe Closet Oatmeal Milk Brown     26.50      90.0        70.0
# !!! Citra Pale !!!                    47.32      60.0        75.0
# !!! IPA !!!                           47.32      90.0        75.0
# ...                                     ...       ...         ...
# �vralids old oak                      16.00      60.0        70.0
# �vslapps�l                            13.00      60.0        70.0
# �yvind porter                         31.00      60.0        85.0
# ��gua de Col�nia                      32.00      60.0        70.0
# ��rea de Prote��o Ambiental           35.00      60.0        77.0
#
# [59145 rows x 8 columns]

# %%
beersReviewANDRecipe = pd.merge(dfBeersReview,dfBeersRecipe,on = "beer_name")
beersReviewANDRecipe
# Out:
#                         brewery_name  review_overall  review_aroma  \
# 0              Broad Ripple Brew Pub             4.0           3.5
# 1       District ChopHouse & Brewery             4.0           4.0
# 2       District ChopHouse & Brewery             4.0           3.0
# 3       District ChopHouse & Brewery             3.0           2.5
# 4       District ChopHouse & Brewery             3.5           3.0
# ...                              ...             ...           ...
# 205697   The Defiant Brewing Company             4.0           4.0
# 205698   The Defiant Brewing Company             4.5           4.0
# 205699   The Defiant Brewing Company             4.0           4.0
# 205700   The Defiant Brewing Company             4.5           5.0
# 205701   The Defiant Brewing Company             3.5           4.0
#
#         review_appearance              beer_style  review_palate  \
# 0                     4.0       English Brown Ale            3.5
# 1                     4.0       English Brown Ale            4.0
# 2                     3.5       English Brown Ale            4.0
# 3                     3.5       English Brown Ale            3.0
# 4                     3.5       English Brown Ale            3.5
# ...                   ...                     ...            ...
# 205697                3.5            American IPA            4.5
# 205698                4.0            American IPA            4.0
# 205699                4.5            American IPA            4.0
# 205700                5.0  Russian Imperial Stout            4.5
# 205701                4.0       English Brown Ale            3.5
#
#         review_taste          beer_name  beer_abv     OG        FG       ABV  \
# 0                3.5          Nut Brown       4.7  1.051  1.012636  5.031818
# 1                4.0          Nut Brown       NaN  1.051  1.012636  5.031818
# 2                4.0          Nut Brown       NaN  1.051  1.012636  5.031818
# 3                3.5          Nut Brown       NaN  1.051  1.012636  5.031818
# 4                3.0          Nut Brown       NaN  1.051  1.012636  5.031818
# ...              ...                ...       ...    ...       ...       ...
# 205697           4.0         Medusa IPA       6.5  1.062  1.012500  6.530000
# 205698           4.5         Medusa IPA       6.5  1.062  1.012500  6.530000
# 205699           4.0         Medusa IPA       6.5  1.062  1.012500  6.530000
# 205700           4.5              Death      15.0  1.085  1.018000  8.800000
# 205701           3.5  English Nut Brown       NaN  1.048  1.011000  4.880000
#
#               IBU      Color   BoilSize   BoilTime  Efficiency
# 0       27.233636  20.935455  21.093636  57.727273   57.090909
# 1       27.233636  20.935455  21.093636  57.727273   57.090909
# 2       27.233636  20.935455  21.093636  57.727273   57.090909
# 3       27.233636  20.935455  21.093636  57.727273   57.090909
# 4       27.233636  20.935455  21.093636  57.727273   57.090909
# ...           ...        ...        ...        ...         ...
# 205697  63.705000   9.460000  55.835000  60.000000   72.500000
# 205698  63.705000   9.460000  55.835000  60.000000   72.500000
# 205699  63.705000   9.460000  55.835000  60.000000   72.500000
# 205700  44.790000   8.870000  24.610000  60.000000   70.000000
# 205701  20.940000  18.090000  24.610000  60.000000   65.000000
#
# [205702 rows x 17 columns]

# %%
for el in beersReviewANDRecipe[["beer_name","beer_abv", "ABV"]]:
    print(el)
    if(el["beer_abv"] == None):
        el["beer_abv"] = beersReviewANDRecipe[beersReviewANDRecipe[el["beer_name"]]['ABV']]
# Out:
# beer_name
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2aef06b2e750> in <module>
#       1 for el in beersReviewANDRecipe[["beer_name","beer_abv", "ABV"]]:
#       2     print(el)
# ----> 3     if(el["beer_abv"] == None):
#       4         el["beer_abv"] = beersReviewANDRecipe[beersReviewANDRecipe[el["beer_name"]]['ABV']]
#
# TypeError: string indices must be integers

# %%
beersReviewANDRecipe["beer_abv"] = beersReviewANDRecipe["ABV"]

# %%
beersReviewANDRecipe[beersReviewANDRecipe['beer_abv'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brewery_name, review_overall, review_aroma, review_appearance, beer_style, review_palate, review_taste, beer_name, beer_abv, OG, FG, ABV, IBU, Color, BoilSize, BoilTime, Efficiency]
# Index: []

# %%
beersReviewANDRecipe[beersReviewANDRecipe['beer_abv'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brewery_name, review_overall, review_aroma, review_appearance, beer_style, review_palate, review_taste, beer_name, beer_abv, OG, FG, ABV, IBU, Color, BoilSize, BoilTime, Efficiency]
# Index: []

# %%
beersReviewANDRecipe = beersReviewANDRecipe.drop(columns=["ABV"])
beersReviewANDRecipe.head()
# Out:
#                    brewery_name  review_overall  review_aroma  \
# 0         Broad Ripple Brew Pub             4.0           3.5
# 1  District ChopHouse & Brewery             4.0           4.0
# 2  District ChopHouse & Brewery             4.0           3.0
# 3  District ChopHouse & Brewery             3.0           2.5
# 4  District ChopHouse & Brewery             3.5           3.0
#
#    review_appearance         beer_style  review_palate  review_taste  \
# 0                4.0  English Brown Ale            3.5           3.5
# 1                4.0  English Brown Ale            4.0           4.0
# 2                3.5  English Brown Ale            4.0           4.0
# 3                3.5  English Brown Ale            3.0           3.5
# 4                3.5  English Brown Ale            3.5           3.0
#
#    beer_name  beer_abv     OG        FG        IBU      Color   BoilSize  \
# 0  Nut Brown  5.031818  1.051  1.012636  27.233636  20.935455  21.093636
# 1  Nut Brown  5.031818  1.051  1.012636  27.233636  20.935455  21.093636
# 2  Nut Brown  5.031818  1.051  1.012636  27.233636  20.935455  21.093636
# 3  Nut Brown  5.031818  1.051  1.012636  27.233636  20.935455  21.093636
# 4  Nut Brown  5.031818  1.051  1.012636  27.233636  20.935455  21.093636
#
#     BoilTime  Efficiency
# 0  57.727273   57.090909
# 1  57.727273   57.090909
# 2  57.727273   57.090909
# 3  57.727273   57.090909
# 4  57.727273   57.090909

# %%
beersByName =  beersReviewANDRecipe.groupby('beer_name').mean()
beersByName
# Out:
#                  review_overall  review_aroma  review_appearance  \
# beer_name
# #14                    3.857143      3.785714           3.857143
# #9                     3.539528      3.434466           3.501040
# 'Tis The Saison        3.750000      3.250000           2.500000
# 4x4                    4.000000      3.500000           3.666667
# 60 Minute IPA          4.172727      3.996768           3.966061
# ...                         ...           ...                ...
# Yule                   3.500000      4.000000           4.000000
# Yuletide Ale           3.923077      3.576923           3.769231
# Zombie Dust            4.512723      4.543257           4.215013
# Zomerbier              4.000000      3.772727           3.727273
# Zwickel                4.046875      3.578125           3.687500
#
#                  review_palate  review_taste  beer_abv         OG       FG  \
# beer_name
# #14                   3.714286      3.785714  6.015000   7.305500  1.90087
# #9                    3.398058      3.396671  5.380000  13.099200  3.06868
# 'Tis The Saison       4.000000      3.750000  4.890000   1.048000  1.01100
# 4x4                   3.666667      3.833333  5.520000   1.058000  1.01600
# 60 Minute IPA         4.006667      4.118990  6.210000   1.058000  1.01100
# ...                        ...           ...       ...        ...      ...
# Yule                  3.000000      4.000000  7.520000   1.071000  1.01300
# Yuletide Ale          3.653846      3.730769  7.540000   1.077000  1.01900
# Zombie Dust           4.258270      4.492366  6.233478   1.063565  1.01600
# Zomerbier             3.636364      3.818182  4.310000   1.049000  1.01600
# Zwickel               3.796875      3.843750  6.340000  14.652700  2.89791
#
#                        IBU      Color   BoilSize   BoilTime  Efficiency
# beer_name
# #14              58.485000   7.425000  23.100000  65.000000   67.000000
# #9               28.960000  47.970000  28.000000  60.000000   70.000000
# 'Tis The Saison  25.390000   7.690000  24.610000  60.000000   70.000000
# 4x4              63.340000  32.500000  25.000000  90.000000   83.000000
# 60 Minute IPA    65.700000   3.510000  22.000000  60.000000   35.000000
# ...                    ...        ...        ...        ...         ...
# Yule             54.700000  19.650000  11.360000  60.000000   80.000000
# Yuletide Ale     20.590000  17.480000   6.000000  60.000000   35.000000
# Zombie Dust      63.047391   8.803478  27.713913  63.913043   68.043478
# Zomerbier        39.550000   6.200000  15.000000  60.000000   78.000000
# Zwickel          24.470000  14.150000   6.000000  60.000000   46.500000
#
# [2019 rows x 13 columns]

# %%
col = ["review_overall", "review_taste"]
g = sb.pairplot(
    data=beersByName[col]
)

# %%
sb.heatmap(beersByName.corr())
# Out:
# <AxesSubplot:>

# %%
beersByName.corr()["review_overall"].sort_values(ascending=False)
# Out:
# review_overall       1.000000
# review_taste         0.867247
# review_palate        0.814251
# review_aroma         0.731748
# review_appearance    0.609474
# IBU                  0.086274
# beer_abv             0.054998
# Color                0.037074
# FG                   0.035013
# OG                   0.027845
# BoilTime             0.024821
# Efficiency           0.015177
# BoilSize            -0.008599
# Name: review_overall, dtype: float64

# %%
beersByName.corr()["IBU"].sort_values(ascending=False)
# Out:
# IBU                  1.000000
# beer_abv             0.328515
# review_aroma         0.150086
# review_appearance    0.126374
# review_taste         0.114800
# review_palate        0.105020
# review_overall       0.086274
# Color                0.068201
# BoilTime             0.045874
# BoilSize             0.002037
# FG                  -0.009389
# OG                  -0.013387
# Efficiency          -0.045924
# Name: IBU, dtype: float64

# %%
#beersByName = beersByName.reset_index()
beersByName.sort_values(by="beer_abv", ascending=False)[["beer_name", "beer_abv"]].head(10)
# Out:
#                   beer_name  beer_abv
# 1221                Maximus     20.44
# 1848                  Tokyo     18.26
# 278     Black Tokyo Horizon     17.46
# 168     Belgian Barley Wine     16.08
# 1128         Kasteel Donker     12.18
# 1891                      V     12.01
# 1477  Quilter's Irish Death     11.95
# 770                Fireside     11.89
# 146                 Baronen     11.82
# 692                 Eisbock     11.82

# %%
beersByb =  beersReviewANDRecipe.groupby('brewery_name').mean()
beersByb
# Out:
#                                 review_overall  review_aroma  \
# brewery_name
# 10 Barrel Brewing Co.                 4.000000      3.000000
# 1516 Brewing Company                  4.000000      3.666667
# 16 Mile Brewing Company               4.200000      4.200000
# 1702 / The Address Brewing Co.        4.000000      4.500000
# 1st City Brewery and Grill            4.500000      4.250000
# ...                                        ...           ...
# Zum Stiefel                           3.500000      3.000000
# À l’abri de la Tempête                3.400000      3.300000
# Ægir Bryggeri                         4.000000      4.500000
# Ölands Gårdsbryggeri                  3.250000      4.000000
# Ørbæk Bryggeri                        3.571429      3.714286
#
#                                 review_appearance  review_palate  \
# brewery_name
# 10 Barrel Brewing Co.                    3.000000       3.500000
# 1516 Brewing Company                     4.000000       3.500000
# 16 Mile Brewing Company                  4.100000       3.900000
# 1702 / The Address Brewing Co.           4.000000       4.000000
# 1st City Brewery and Grill               4.500000       4.500000
# ...                                           ...            ...
# Zum Stiefel                              3.166667       3.333333
# À l’abri de la Tempête                   3.000000       3.400000
# Ægir Bryggeri                            4.000000       4.000000
# Ölands Gårdsbryggeri                     3.250000       2.750000
# Ørbæk Bryggeri                           3.642857       3.714286
#
#                                 review_taste  beer_abv        OG        FG  \
# brewery_name
# 10 Barrel Brewing Co.               3.500000  5.060000  1.050175  1.011625
# 1516 Brewing Company                3.666667  5.138554  1.104468  1.022803
# 16 Mile Brewing Company             4.200000  6.610000  1.060000  1.010000
# 1702 / The Address Brewing Co.      4.000000  7.315000  1.071000  1.015000
# 1st City Brewery and Grill          4.500000  5.518136  1.057653  1.015644
# ...                                      ...       ...       ...       ...
# Zum Stiefel                         3.166667  5.191190  1.537658  1.109005
# À l’abri de la Tempête              3.400000  5.290000  1.050000  1.010000
# Ægir Bryggeri                       4.000000  6.610000  1.060000  1.010000
# Ölands Gårdsbryggeri                3.250000  5.167692  1.051154  1.012077
# Ørbæk Bryggeri                      3.857143  6.194046  1.181444  1.032473
#
#                                       IBU      Color    BoilSize   BoilTime  \
# brewery_name
# 10 Barrel Brewing Co.           33.354000   5.803500   26.422250  67.125000
# 1516 Brewing Company            41.122678   9.418650   44.117037  61.157407
# 16 Mile Brewing Company         65.790000   4.600000   37.000000  60.000000
# 1702 / The Address Brewing Co.  88.530000   8.795000   58.200000  75.000000
# 1st City Brewery and Grill      35.384153  35.719915   46.428644  63.728814
# ...                                   ...        ...         ...        ...
# Zum Stiefel                     18.270952   4.784460  116.747095  70.317460
# À l’abri de la Tempête          30.910000   2.720000    9.460000  60.000000
# Ægir Bryggeri                   65.790000   4.600000   37.000000  60.000000
# Ölands Gårdsbryggeri            48.818462   6.378462   22.180000  60.000000
# Ørbæk Bryggeri                  45.939587  16.450300   30.108099  61.025276
#
#                                 Efficiency
# brewery_name
# 10 Barrel Brewing Co.            64.050000
# 1516 Brewing Company             66.817415
# 16 Mile Brewing Company          70.000000
# 1702 / The Address Brewing Co.   69.000000
# 1st City Brewery and Grill       67.377119
# ...                                    ...
# Zum Stiefel                      69.842857
# À l’abri de la Tempête           35.000000
# Ægir Bryggeri                    70.000000
# Ölands Gårdsbryggeri             66.461538
# Ørbæk Bryggeri                   58.573714
#
# [2095 rows x 13 columns]

# %%
beersByb = beersByb.reset_index()
beersByb.sort_values(by="review_overall", ascending=False)[["brewery_name", "review_overall"]].head(10)
# Out:
#                                brewery_name  review_overall
# 248                        Boston Breweries             5.0
# 506                       Coach's Brewhouse             5.0
# 1077                             Kunino Cho             5.0
# 1469                         Pipkin Brewery             5.0
# 1796                     TBonz Gill & Grill             5.0
# 1648  Sekinoichi-shuzou, Iwate-kura Brewery             5.0
# 2039             Wild Creek Brewing Company             5.0
# 204                     Black Lotus Brewery             5.0
# 188                        Binghams Brewery             5.0
# 500               Clay Pipe Brewing Company             5.0

# %%
import numpy as np
from datetime import datetime

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn_rvm import EMRVC
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
with open('recipes_full.txt') as f:
    dfBeersRecipe = pd.DataFrame(json.loads(f.read()))
dfBeersRecipe = dfBeersRecipe.transpose()

# %%
dfBeersRecipe[dfBeersRecipe['style'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, url, method, style, batch, og, fg, abv, ibu, color, ph mash, fermentables, hops, hops Summary, other, yeast, rating, num rating, views]
# Index: []

# %%
dfBeersRecipe = dfBeersRecipe.drop(columns=["views", "num rating", "rating"])

# %%
dfBeersRecipe.head()
# Out:
#                                        name  \
# 0                         Vanilla Cream Ale
# 1        Avg. Perfect Northeast IPA (NEIPA)
# 2              Sierra Nevada Pale Ale Clone
# 3             Zombie Dust Clone - ALL GRAIN
# 4  Russian River Pliny the Elder (original)
#
#                                                  url     method  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale  All Grain
# 1  /homebrew/recipe/view/363082/avg-perfect-north...  All Grain
# 2  /homebrew/recipe/view/28546/sierra-nevada-pale...  All Grain
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...  All Grain
# 4  /homebrew/recipe/view/37534/russian-river-plin...  All Grain
#
#                             style batch     og     fg   abv     ibu color  \
# 0                       Cream Ale  21.8  1.055  1.013  5.48   19.44  4.83
# 1  Specialty IPA: New England IPA  21.8  1.062  1.013   6.5   59.26   5.2
# 2               American Pale Ale  24.6  1.055  1.013  5.58   39.79   8.0
# 3                    American IPA  22.7  1.061  1.016  5.94   62.42   8.5
# 4                    Imperial IPA  22.7  1.072  1.018  7.09  232.89  6.33
#
#   ph mash                                       fermentables  \
# 0      -1  [[2.381, American - Pale 2-Row, 37.0, 1.8, 44....
# 1    5.49  [[4.876, American - Pale 2-Row, 37.0, 1.8, 77....
# 2    5.67  [[5.216, American - Pale 2-Row, 37.0, 1.8, 92....
# 3    5.81  [[5.33, American - Pale 2-Row, 37.0, 1.8, 81.7...
# 4      -1  [[6.01, American - Pale 2-Row, 37.0, 1.8, 87.2...
#
#                                                 hops  \
# 0  [[14.0, Cascade, Pellet, 6.2, Boil, 60 min, 11...
# 1  [[28.0, Citra, Pellet, 12.6, Boil, 10 min, 13....
# 2  [[14.0, Magnum, Pellet, 15.0, Boil, 60 min, 22...
# 3  [[21.0, Citra, Pellet, 11.0, First Wort, 0 min...
# 4  [[98.0, Columbus, Pellet, 15.0, Boil, 90 min, ...
#
#                                         hops Summary  \
# 0  [[28.0, Cascade (Pellet), 18.34, 66.6], [14.0,...
# 1  [[133.0, Citra (Pellet), 22.78, 34.6], [154.0,...
# 2  [[14.0, Magnum (Pellet), 22.62, 8.3], [14.0, P...
# 3            [[245.0, Citra (Pellet), 62.42, 100.1]]
# 4  [[154.0, Columbus (Pellet), 203.08, 44.0], [13...
#
#                                                other  \
# 0  [[2 oz, pure vanilla extract, Flavor, Boil, 0 ...
# 1  [[0.50 tsp, Irish Moss, Fining, Boil, 15 min.]...
# 2  [[1 each, Crush whilrfoc Tablet, Water Agt, Bo...
# 3                                                 []
# 4                                                 []
#
#                                                yeast
# 0      [Wyeast - Kölsch 2565, 76%, Low, 56, 70, Yes]
# 1  [Wyeast - London Ale III 1318, 78%, High, 64, ...
# 2  [Fermentis - Safale - American Ale Yeast US-05...
# 3  [Fermentis - Safale - English Ale Yeast S-04, ...
# 4  [Wyeast - American Ale 1056, 75%, Med-Low, 60,...

# %%
dfBeersRecipe = dfBeersRecipe.rename(columns={'name': 'beer_name'})
#dfBeersRecipe2 = dfBeersRecipe2.rename(columns={'Name': 'beer_name'})

# %%
#dfBeersRecipe2 = dfBeersRecipe2.drop_duplicates(subset=['beer_name'])
dfBeersRecipe = dfBeersRecipe.drop_duplicates(subset=['beer_name'])

# %%
beersReviewANDRecipe = pd.merge(dfBeersReview,dfBeersRecipe,on = "beer_name")

# %%
beersReviewANDRecipe
# Out:
#                        brewery_name  review_overall  review_aroma  \
# 0           Caldera Brewing Company             3.0           3.0
# 1           Caldera Brewing Company             4.0           4.0
# 2           Caldera Brewing Company             4.5           3.0
# 3           Caldera Brewing Company             4.0           3.5
# 4           Caldera Brewing Company             3.0           3.5
# ...                             ...             ...           ...
# 271720  The Defiant Brewing Company             4.0           4.0
# 271721  The Defiant Brewing Company             4.5           5.0
# 271722  The Defiant Brewing Company             3.5           4.0
# 271723  The Defiant Brewing Company             4.0           4.0
# 271724  The Defiant Brewing Company             4.0           3.5
#
#         review_appearance              beer_style  review_palate  \
# 0                     4.0  American Adjunct Lager            2.0
# 1                     4.0  American Adjunct Lager            4.0
# 2                     3.5  American Adjunct Lager            3.5
# 3                     3.5  American Adjunct Lager            3.5
# 4                     3.5  American Adjunct Lager            3.0
# ...                   ...                     ...            ...
# 271720                4.5            American IPA            4.0
# 271721                5.0  Russian Imperial Stout            4.5
# 271722                4.0       English Brown Ale            3.5
# 271723                4.0     American Pale Lager            4.0
# 271724                3.5     American Pale Lager            3.0
#
#         review_taste          beer_name  beer_abv  \
# 0                3.0    Lawnmower Lager       3.9
# 1                4.0    Lawnmower Lager       3.9
# 2                3.5    Lawnmower Lager       3.9
# 3                3.5    Lawnmower Lager       3.9
# 4                3.0    Lawnmower Lager       3.9
# ...              ...                ...       ...
# 271720           4.0         Medusa IPA       6.5
# 271721           4.5              Death      15.0
# 271722           3.5  English Nut Brown       NaN
# 271723           4.0  Prohibition Lager       NaN
# 271724           3.5  Prohibition Lager       NaN
#
#                                                    url  ...     fg   abv  \
# 0         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 1         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 2         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 3         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 4         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# ...                                                ...  ...    ...   ...
# 271720         /homebrew/recipe/view/411140/medusa-ipa  ...  1.012  6.35
# 271721              /homebrew/recipe/view/295042/death  ...  1.018   8.8
# 271722  /homebrew/recipe/view/120797/english-nut-brown  ...  1.011  4.88
# 271723  /homebrew/recipe/view/832551/prohibition-lager  ...  1.017  5.08
# 271724  /homebrew/recipe/view/832551/prohibition-lager  ...  1.017  5.08
#
#           ibu  color ph mash  \
# 0       10.19   2.57     5.6
# 1       10.19   2.57     5.6
# 2       10.19   2.57     5.6
# 3       10.19   2.57     5.6
# 4       10.19   2.57     5.6
# ...       ...    ...     ...
# 271720  63.03  12.47      -1
# 271721  61.69   8.87      -1
# 271722  19.94  18.09      -1
# 271723  10.27   4.51      -1
# 271724  10.27   4.51      -1
#
#                                              fermentables  \
# 0       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 1       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 2       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 3       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 4       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# ...                                                   ...
# 271720  [[3.629, United Kingdom - Maris Otter Pale, 38...
# 271721  [[5.443, United Kingdom - Maris Otter Pale, 38...
# 271722  [[0.113, Belgian - Biscuit, 35.0, 23.0, 2.3], ...
# 271723  [[4.082, United Kingdom - Maris Otter Pale, 38...
# 271724  [[4.082, United Kingdom - Maris Otter Pale, 38...
#
#                                                      hops  \
# 0       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 1       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 2       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 3       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 4       [[28.0, Yakima Chief Hops - German Hallertau, ...
# ...                                                   ...
# 271720  [[14.0, Yakima Valley Hops - idaho 7, Pellet, ...
# 271721  [[28.0, El Dorado, Pellet, 15.7, Boil, 0 min, ...
# 271722  [[28.0, Fuggles, Pellet, 4.5, Boil, 60 min, 16...
# 271723  [[28.0, Crystal, Pellet, 4.3, Boil, 60 min, 7....
# 271724  [[28.0, Crystal, Pellet, 4.3, Boil, 60 min, 7....
#
#                                              hops Summary  \
# 0       [[28.0, Yakima Chief Hops - German Hallertau (...
# 1       [[28.0, Yakima Chief Hops - German Hallertau (...
# 2       [[28.0, Yakima Chief Hops - German Hallertau (...
# 3       [[28.0, Yakima Chief Hops - German Hallertau (...
# 4       [[28.0, Yakima Chief Hops - German Hallertau (...
# ...                                                   ...
# 271720  [[42.0, Yakima Valley Hops - idaho 7 (Pellet),...
# 271721  [[56.0, El Dorado (Pellet), 31.55, 33.4], [56....
# 271722           [[42.0, Fuggles (Pellet), 19.94, 100.0]]
# 271723  [[56.0, Crystal (Pellet), 9.99, 66.6], [28.0, ...
# 271724  [[56.0, Crystal (Pellet), 9.99, 66.6], [28.0, ...
#
#                                                     other  \
# 0       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 1       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 2       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 3       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 4       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# ...                                                   ...
# 271720                                                 []
# 271721                                                 []
# 271722                                                 []
# 271723                                                 []
# 271724                                                 []
#
#                                                     yeast
# 0       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 1       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 2       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 3       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 4       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# ...                                                   ...
# 271720  [Fermentis - Safale - American Ale Yeast US-05...
# 271721  [Danstar - Nottingham Ale Yeast, 77%, High, 57...
# 271722  [Danstar - Nottingham Ale Yeast, 77%, High, 57...
# 271723  [Wyeast - Bavarian Lager 2206, 70%, Med-High, ...
# 271724  [Wyeast - Bavarian Lager 2206, 70%, Med-High, ...
#
# [271725 rows x 24 columns]

# %%
beersReviewANDRecipeMain = beersReviewANDRecipe.drop(columns=["brewery_id"])

# %%
beersReviewANDRecipeMain
# Out:
#                        brewery_name  review_overall  review_aroma  \
# 0           Caldera Brewing Company             3.0           3.0
# 1           Caldera Brewing Company             4.0           4.0
# 2           Caldera Brewing Company             4.5           3.0
# 3           Caldera Brewing Company             4.0           3.5
# 4           Caldera Brewing Company             3.0           3.5
# ...                             ...             ...           ...
# 271720  The Defiant Brewing Company             4.0           4.0
# 271721  The Defiant Brewing Company             4.5           5.0
# 271722  The Defiant Brewing Company             3.5           4.0
# 271723  The Defiant Brewing Company             4.0           4.0
# 271724  The Defiant Brewing Company             4.0           3.5
#
#         review_appearance              beer_style  review_palate  \
# 0                     4.0  American Adjunct Lager            2.0
# 1                     4.0  American Adjunct Lager            4.0
# 2                     3.5  American Adjunct Lager            3.5
# 3                     3.5  American Adjunct Lager            3.5
# 4                     3.5  American Adjunct Lager            3.0
# ...                   ...                     ...            ...
# 271720                4.5            American IPA            4.0
# 271721                5.0  Russian Imperial Stout            4.5
# 271722                4.0       English Brown Ale            3.5
# 271723                4.0     American Pale Lager            4.0
# 271724                3.5     American Pale Lager            3.0
#
#         review_taste          beer_name  beer_abv  \
# 0                3.0    Lawnmower Lager       3.9
# 1                4.0    Lawnmower Lager       3.9
# 2                3.5    Lawnmower Lager       3.9
# 3                3.5    Lawnmower Lager       3.9
# 4                3.0    Lawnmower Lager       3.9
# ...              ...                ...       ...
# 271720           4.0         Medusa IPA       6.5
# 271721           4.5              Death      15.0
# 271722           3.5  English Nut Brown       NaN
# 271723           4.0  Prohibition Lager       NaN
# 271724           3.5  Prohibition Lager       NaN
#
#                                                    url  ...     fg   abv  \
# 0         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 1         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 2         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 3         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# 4         /homebrew/recipe/view/936108/lawnmower-lager  ...  1.013  4.62
# ...                                                ...  ...    ...   ...
# 271720         /homebrew/recipe/view/411140/medusa-ipa  ...  1.012  6.35
# 271721              /homebrew/recipe/view/295042/death  ...  1.018   8.8
# 271722  /homebrew/recipe/view/120797/english-nut-brown  ...  1.011  4.88
# 271723  /homebrew/recipe/view/832551/prohibition-lager  ...  1.017  5.08
# 271724  /homebrew/recipe/view/832551/prohibition-lager  ...  1.017  5.08
#
#           ibu  color ph mash  \
# 0       10.19   2.57     5.6
# 1       10.19   2.57     5.6
# 2       10.19   2.57     5.6
# 3       10.19   2.57     5.6
# 4       10.19   2.57     5.6
# ...       ...    ...     ...
# 271720  63.03  12.47      -1
# 271721  61.69   8.87      -1
# 271722  19.94  18.09      -1
# 271723  10.27   4.51      -1
# 271724  10.27   4.51      -1
#
#                                              fermentables  \
# 0       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 1       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 2       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 3       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# 4       [[4.309, Briess - Pilsen Malt 2-Row, 37.0, 1.2...
# ...                                                   ...
# 271720  [[3.629, United Kingdom - Maris Otter Pale, 38...
# 271721  [[5.443, United Kingdom - Maris Otter Pale, 38...
# 271722  [[0.113, Belgian - Biscuit, 35.0, 23.0, 2.3], ...
# 271723  [[4.082, United Kingdom - Maris Otter Pale, 38...
# 271724  [[4.082, United Kingdom - Maris Otter Pale, 38...
#
#                                                      hops  \
# 0       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 1       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 2       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 3       [[28.0, Yakima Chief Hops - German Hallertau, ...
# 4       [[28.0, Yakima Chief Hops - German Hallertau, ...
# ...                                                   ...
# 271720  [[14.0, Yakima Valley Hops - idaho 7, Pellet, ...
# 271721  [[28.0, El Dorado, Pellet, 15.7, Boil, 0 min, ...
# 271722  [[28.0, Fuggles, Pellet, 4.5, Boil, 60 min, 16...
# 271723  [[28.0, Crystal, Pellet, 4.3, Boil, 60 min, 7....
# 271724  [[28.0, Crystal, Pellet, 4.3, Boil, 60 min, 7....
#
#                                              hops Summary  \
# 0       [[28.0, Yakima Chief Hops - German Hallertau (...
# 1       [[28.0, Yakima Chief Hops - German Hallertau (...
# 2       [[28.0, Yakima Chief Hops - German Hallertau (...
# 3       [[28.0, Yakima Chief Hops - German Hallertau (...
# 4       [[28.0, Yakima Chief Hops - German Hallertau (...
# ...                                                   ...
# 271720  [[42.0, Yakima Valley Hops - idaho 7 (Pellet),...
# 271721  [[56.0, El Dorado (Pellet), 31.55, 33.4], [56....
# 271722           [[42.0, Fuggles (Pellet), 19.94, 100.0]]
# 271723  [[56.0, Crystal (Pellet), 9.99, 66.6], [28.0, ...
# 271724  [[56.0, Crystal (Pellet), 9.99, 66.6], [28.0, ...
#
#                                                     other  \
# 0       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 1       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 2       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 3       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# 4       [[1 each, Whirlfloc, Water Agt, Boil, 15 min.]...
# ...                                                   ...
# 271720                                                 []
# 271721                                                 []
# 271722                                                 []
# 271723                                                 []
# 271724                                                 []
#
#                                                     yeast
# 0       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 1       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 2       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 3       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# 4       [Imperial Yeast - L05 Cablecar, 71%, Medium Hi...
# ...                                                   ...
# 271720  [Fermentis - Safale - American Ale Yeast US-05...
# 271721  [Danstar - Nottingham Ale Yeast, 77%, High, 57...
# 271722  [Danstar - Nottingham Ale Yeast, 77%, High, 57...
# 271723  [Wyeast - Bavarian Lager 2206, 70%, Med-High, ...
# 271724  [Wyeast - Bavarian Lager 2206, 70%, Med-High, ...
#
# [271725 rows x 24 columns]

# %%
beersByName =  beersReviewANDRecipeMain.groupby('beer_name').mean()

# %%
beersByName.size
# Out:
# 17700

# %%
beersByName
# Out:
#              review_overall  review_aroma  review_appearance  review_palate  \
# beer_name
# #10                4.000000      4.000000           4.000000       4.000000
# #100               4.000000      3.500000           4.000000       4.000000
# #13                4.000000      4.000000           3.833333       4.166667
# #14                3.857143      3.785714           3.857143       3.714286
# #9                 3.539528      3.434466           3.501040       3.398058
# ...                     ...           ...                ...            ...
# Zeus Juice         3.500000      4.000000           4.000000       4.000000
# Zombie Dust        4.512723      4.543257           4.215013       4.258270
# Zomerbier          4.000000      3.772727           3.727273       3.636364
# Zwickel            4.046875      3.578125           3.687500       3.796875
# Ægir IPA           4.000000      4.000000           3.000000       2.500000
#
#              review_taste  beer_abv
# beer_name
# #10              3.000000       9.0
# #100             4.000000       6.5
# #13              3.833333       6.2
# #14              3.785714       8.0
# #9               3.396671       5.1
# ...                   ...       ...
# Zeus Juice       3.500000       NaN
# Zombie Dust      4.492366       6.2
# Zomerbier        3.818182       5.6
# Zwickel          3.843750       5.2
# Ægir IPA         3.500000       6.5
#
# [2950 rows x 6 columns]

# %%
col = ["review_overall", "beer_abv","IBU"]
g = sb.pairplot(
    data=beersByName[col]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b0cf1eb67504> in <module>
#       1 col = ["review_overall", "beer_abv","IBU"]
#       2 g = sb.pairplot(
# ----> 3     data=beersByName[col]
#       4 )
#
# ~\.conda\envs\test\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\.conda\envs\test\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\.conda\envs\test\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['IBU'] not in index"

# %%
beersByRate =  beersByName.groupby('review_overall').mean()

# %%
beersByRate

# %%
beersByRate = beersByRate.reset_index()
col = ["review_overall", "beer_abv", "IBU", "review_taste"]
g = sb.pairplot(
    data=beersByRate[col]
)

# %%
sb.heatmap(beersByName.corr())

# %%
beersByName.corr()["review_overall"].sort_values(ascending=False)І
